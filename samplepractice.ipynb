# %%
students = [
    {"name": "민수", "score": 85},
    {"name": "지영", "score": 72},
    {"name": "현우", "score": 91},
    {"name": "수진", "score": 88}
]

good_student =[]

for student in students:
    name = student["name"],
    score = student["score"]

    if score >= 80:
        good_student.append(student)

for student in good_student:
    print(
        f"{student['name']}",
        f"{student['score']}점"
    )
# Out:
# 민수 85점
# 현우 91점
# 수진 88점
